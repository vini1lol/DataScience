# %% [markdown]
# ##Covid-19

# %%
import pandas as pd
import seaborn as sns
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Pegando os dados (dados retirados de https://www.kaggle.com/unanimad/corona-virus-brazil#brazil_covid19.csv)

# %%
dados2 = pd.read_csv("/content/drive/My Drive/Meus testes de dados/brazil_covid19.csv")
dados2
# Out:
#             date        region               state  cases  deaths
# 0     2020-01-30  Centro-Oeste    Distrito Federal      0       0
# 1     2020-01-30  Centro-Oeste               Goiás      0       0
# 2     2020-01-30  Centro-Oeste         Mato Grosso      0       0
# 3     2020-01-30  Centro-Oeste  Mato Grosso do Sul      0       0
# 4     2020-01-30      Nordeste             Alagoas      0       0
# ...          ...           ...                 ...    ...     ...
# 2371  2020-04-26       Sudeste      Rio de Janeiro   7111     645
# 2372  2020-04-26       Sudeste           São Paulo  20715    1700
# 2373  2020-04-26           Sul              Paraná   1156      72
# 2374  2020-04-26           Sul   Rio Grande do Sul   1166      35
# 2375  2020-04-26           Sul      Santa Catarina   1235      42
#
# [2376 rows x 5 columns]

# %%
dadosLimpo = (dados2['cases']==0) & (dados2['deaths']==0)
dadosLimpo = dados2[~dadosLimpo]
dadosLimpo
# Out:
#             date   region              state  cases  deaths
# 752   2020-02-26  Sudeste          São Paulo      1       0
# 779   2020-02-27  Sudeste          São Paulo      1       0
# 806   2020-02-28  Sudeste          São Paulo      1       0
# 833   2020-02-29  Sudeste          São Paulo      2       0
# 860   2020-03-01  Sudeste          São Paulo      2       0
# ...          ...      ...                ...    ...     ...
# 2371  2020-04-26  Sudeste     Rio de Janeiro   7111     645
# 2372  2020-04-26  Sudeste          São Paulo  20715    1700
# 2373  2020-04-26      Sul             Paraná   1156      72
# 2374  2020-04-26      Sul  Rio Grande do Sul   1166      35
# 2375  2020-04-26      Sul     Santa Catarina   1235      42
#
# [1194 rows x 5 columns]

# %%
dadosLimpo.index = range(dadosLimpo.shape[0])
dadosLimpo.to_csv("/content/drive/My Drive/Meus testes de dados/dados.csv")
dadosLimpo
# Out:
#             date   region              state  cases  deaths
# 0     2020-02-26  Sudeste          São Paulo      1       0
# 1     2020-02-27  Sudeste          São Paulo      1       0
# 2     2020-02-28  Sudeste          São Paulo      1       0
# 3     2020-02-29  Sudeste          São Paulo      2       0
# 4     2020-03-01  Sudeste          São Paulo      2       0
# ...          ...      ...                ...    ...     ...
# 1189  2020-04-26  Sudeste     Rio de Janeiro   7111     645
# 1190  2020-04-26  Sudeste          São Paulo  20715    1700
# 1191  2020-04-26      Sul             Paraná   1156      72
# 1192  2020-04-26      Sul  Rio Grande do Sul   1166      35
# 1193  2020-04-26      Sul     Santa Catarina   1235      42
#
# [1194 rows x 5 columns]

# %% [markdown]
# ## Dados por estado

# %%
d =dadosLimpo['state'].unique()
d
# Out:
# array(['São Paulo', 'Rio de Janeiro', 'Bahia', 'Espírito Santo',
#        'Distrito Federal', 'Alagoas', 'Minas Gerais', 'Rio Grande do Sul',
#        'Pernambuco', 'Paraná', 'Goiás', 'Rio Grande do Norte',
#        'Santa Catarina', 'Sergipe', 'Amazonas', 'Mato Grosso do Sul',
#        'Ceará', 'Paraíba', 'Acre', 'Pará', 'Tocantins', 'Mato Grosso',
#        'Piauí', 'Amapá', 'Rondônia', 'Maranhão', 'Roraima'], dtype=object)

# %%
estado ={}
casos = 0
mortes = 0
for i in range(len(d)):
  aux = dadosLimpo['state'] == d[i]
  aux = dadosLimpo[aux]
  aux.index = range(aux.shape[0])
  for k in range(aux.shape[0]):
    if aux['cases'][k] > 0:
      casos = aux['cases'][k]
  for k in range(aux.shape[0]):
    if aux['deaths'][k] > 0:
      mortes = aux['deaths'][k]
  estado.update( {d[i]:{"casos":casos,"mortes":mortes}})
estado
# Out:
# {'Acre': {'casos': 279, 'mortes': 11},
#  'Alagoas': {'casos': 554, 'mortes': 32},
#  'Amapá': {'casos': 798, 'mortes': 21},
#  'Amazonas': {'casos': 3833, 'mortes': 304},
#  'Bahia': {'casos': 2209, 'mortes': 73},
#  'Ceará': {'casos': 5833, 'mortes': 327},
#  'Distrito Federal': {'casos': 1066, 'mortes': 27},
#  'Espírito Santo': {'casos': 1703, 'mortes': 51},
#  'Goiás': {'casos': 573, 'mortes': 25},
#  'Maranhão': {'casos': 2223, 'mortes': 112},
#  'Mato Grosso': {'casos': 250, 'mortes': 9},
#  'Mato Grosso do Sul': {'casos': 234, 'mortes': 7},
#  'Minas Gerais': {'casos': 1548, 'mortes': 61},
#  'Paraná': {'casos': 1156, 'mortes': 72},
#  'Paraíba': {'casos': 499, 'mortes': 49},
#  'Pará': {'casos': 1867, 'mortes': 100},
#  'Pernambuco': {'casos': 4898, 'mortes': 415},
#  'Piauí': {'casos': 331, 'mortes': 18},
#  'Rio Grande do Norte': {'casos': 825, 'mortes': 44},
#  'Rio Grande do Sul': {'casos': 1166, 'mortes': 35},
#  'Rio de Janeiro': {'casos': 7111, 'mortes': 645},
#  'Rondônia': {'casos': 364, 'mortes': 10},
#  'Roraima': {'casos': 401, 'mortes': 4},
#  'Santa Catarina': {'casos': 1235, 'mortes': 42},
#  'Sergipe': {'casos': 159, 'mortes': 9},
#  'São Paulo': {'casos': 20715, 'mortes': 1700},
#  'Tocantins': {'casos': 58, 'mortes': 2}}

# %%
df_estado = pd.DataFrame(estado)
df_estado=df_estado.transpose()
df_estado.reset_index(level=0,inplace= True)
df_estado.rename(columns={'index':'estado'}, inplace=True)
df_estado.head()
# Out:
#              estado  casos  mortes
# 0         São Paulo  20715    1700
# 1    Rio de Janeiro   7111     645
# 2             Bahia   2209      73
# 3    Espírito Santo   1703      51
# 4  Distrito Federal   1066      27

# %% [markdown]
# ### Casos e mortes por estado

# %%
df_estado.sort_values(by=['casos'], inplace= True, ascending= False)
g = sns.catplot(x='estado',y='casos',data=df_estado, kind="bar",
            palette="GnBu_d", aspect = 2)
for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')
print(g)
df_estado.sort_values(by=['mortes'], inplace= True, ascending= False)
h = sns.catplot(x='estado',y='mortes',data=df_estado, kind="bar",
            palette="GnBu_d", aspect = 2)
for ax in h.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')
print(h)
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x7f2a428d80b8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a428d8048>

# %% [markdown]
# ## Dados do Brasil

# %%
df_Brasil = dados2[['date','state','cases','deaths']]
df_Brasil.head()
# Out:
#          date               state  cases  deaths
# 0  2020-01-30    Distrito Federal      0       0
# 1  2020-01-30               Goiás      0       0
# 2  2020-01-30         Mato Grosso      0       0
# 3  2020-01-30  Mato Grosso do Sul      0       0
# 4  2020-01-30             Alagoas      0       0

# %%
selecao = (df_Brasil['cases'] == 0) & (df_Brasil['deaths'] == 0)
df_Brasil = df_Brasil[~selecao]
df_Brasil.index= range(df_Brasil.shape[0])
df_Brasil
# Out:
#             date              state  cases  deaths
# 0     2020-02-26          São Paulo      1       0
# 1     2020-02-27          São Paulo      1       0
# 2     2020-02-28          São Paulo      1       0
# 3     2020-02-29          São Paulo      2       0
# 4     2020-03-01          São Paulo      2       0
# ...          ...                ...    ...     ...
# 1189  2020-04-26     Rio de Janeiro   7111     645
# 1190  2020-04-26          São Paulo  20715    1700
# 1191  2020-04-26             Paraná   1156      72
# 1192  2020-04-26  Rio Grande do Sul   1166      35
# 1193  2020-04-26     Santa Catarina   1235      42
#
# [1194 rows x 4 columns]

# %%
data = df_Brasil['date'].unique()
data
# Out:
# array(['2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29',
#        '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#        '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#        '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
#        '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16',
#        '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20',
#        '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24',
#        '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-28',
#        '2020-03-29', '2020-03-30', '2020-03-31', '2020-04-01',
#        '2020-04-02', '2020-04-03', '2020-04-04', '2020-04-05',
#        '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09',
#        '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13',
#        '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17',
#        '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21',
#        '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25',
#        '2020-04-26'], dtype=object)

# %%
df_Bdata={}
s=0
for i in range(len(data)):
  s=0
  for j in range(df_Brasil.shape[0]):
    if data[i] == df_Brasil['date'][j]:
      s+= df_Brasil['cases'][j]
      df_Bdata.update({data[i]:s})
df_Bdata = pd.DataFrame(df_Bdata,index=['casos'])
df_Bdata = df_Bdata.transpose()
df_Bdata.reset_index(level=0,inplace=True)
df_Bdata.rename(columns={'index':'data'},inplace=True)
df_Bdata.head(10)
# Out:
#          data  casos
# 0  2020-02-26      1
# 1  2020-02-27      1
# 2  2020-02-28      1
# 3  2020-02-29      2
# 4  2020-03-01      2
# 5  2020-03-02      2
# 6  2020-03-03      2
# 7  2020-03-04      3
# 8  2020-03-05      7
# 9  2020-03-06     13

# %% [markdown]
# ## Quantidade de casos atual no Brasil

# %%
j = sns.catplot(x='data',y='casos',data=df_Bdata, kind="bar",
            palette="GnBu_d", aspect = 3)
for ax in j.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')
print(j)
print('data: {}, casos: {}'.format(df_Bdata['data'][len(data)-1], df_Bdata['casos'][len(data)-1]))
print('Diferença do dia anterior {}'.format(df_Bdata['casos'][len(data)-1]-df_Bdata['casos'][len(data)-2]))
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x7f2a428b8b70>
# data: 2020-04-26, casos: 61888
# Diferença do dia anterior 3379

# %% [markdown]
# # Regressão Linear

# %% [markdown]
# ## Importando train_test_split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##Criando uma Serie pandas para armazenar os casos(y)

# %%
 y = df_Bdata['casos']

# %% [markdown]
# ## Criando uma Serie pandas para armazenar o numero de dias(x)

# %%
X = range(1,len(df_Bdata['casos'])+1)
X = pd.Series(X)

# %% [markdown]
# ## Criando os datasets de treino e de teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=40)
X_train = np.array(X_train)
X_train = X_train.reshape(-1,1)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1)

# %% [markdown]
# ##Importando LinearRegression e metrics da biblioteca scikit-learn

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ##Instanciando a classe LinearRegression()

# %%
modelo = LinearRegression()

# %% [markdown]
# ##Utilizando o método fit() do objeto "modelo" para estimar nosso modelo linear utilizando os dados de TREINO (X_train e y_train)

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ##Obtendo o coeficiente de determinação (R²) do modelo estimado com os dados de TREINO

# %%
print("R² ={}".format(modelo.score(X_train,y_train).round(2)))
# Out:
# R² =0.77

# %% [markdown]
# ##Gerando previsões para os dados de TESTE (X_test) utilizando o método predict() do objeto "modelo"

# %%
y_previsto = modelo.predict(X_test)

# %% [markdown]
# ##Obtendo o coeficiente de determinação (R²) para as previsões do nosso modelo

# %%
print("R² = %s" % metrics.r2_score(y_test,y_previsto).round(2))
# Out:
# R² = 0.69

# %% [markdown]
# ## Obtendo previções a partir do modelo

# %%
entrada = np.array([[60],[61],[70]])
entrada = entrada.reshape(-1,1)
modelo.predict(entrada).round(2)
# Out:
# array([37935.78, 38796.14, 46539.43])

# %% [markdown]
# #Computando os dados de mortes confirmadas

# %%
df_Bdatad={}
s=0
for i in range(len(data)):
  s=0
  for t in range(df_Brasil.shape[0]):
    if data[i] == df_Brasil['date'][t]:
      s+= df_Brasil['deaths'][t]
      df_Bdatad.update({data[i]:s})
df_Bdatad = pd.DataFrame(df_Bdatad,index=['deaths'])
df_Bdatad = df_Bdatad.transpose()
df_Bdatad.reset_index(level=0,inplace=True)
df_Bdatad.rename(columns={'index':'data'},inplace=True)
df_Bdatad.head(10)
# Out:
#          data  deaths
# 0  2020-02-26       0
# 1  2020-02-27       0
# 2  2020-02-28       0
# 3  2020-02-29       0
# 4  2020-03-01       0
# 5  2020-03-02       0
# 6  2020-03-03       0
# 7  2020-03-04       0
# 8  2020-03-05       0
# 9  2020-03-06       0

# %% [markdown]
# ##Quantidade de mortes atual

# %%
k = sns.catplot(x='data',y='deaths',data=df_Bdatad, kind="bar",
            palette="GnBu_d", aspect = 3)
for ax in k.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')

print(k)
print('data: {}, mortes: {}'.format(df_Bdatad['data'][len(data)-1],df_Bdatad['deaths'][len(data)-1]))
print('Diferença do dia anterior {}'.format(df_Bdatad['deaths'][len(data)-1]-df_Bdatad['deaths'][len(data)-2]))
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x7f2a428685f8>
# data: 2020-04-26, mortes: 4205
# Diferença do dia anterior 189

# %% [markdown]
# #Crescimento em cada estado

# %%
dadosPorEstado = {}
for i in range(len(d)):
  dadosPorEstado.update({d[i]:{}})
d[0]
# Out:
# 'São Paulo'

# %%
for i in range(len(d)):
  dadosPorEstado[d[i]] = dadosLimpo[dadosLimpo['state'] == d[i]]
ddframe = dadosPorEstado
dadosPorEstado
frame = pd.DataFrame()
for i in range(len(d)):
  dd = pd.DataFrame(ddframe[d[i]])
  dd.index= range(dd.shape[0])
  frame = pd.concat([frame,dd])
frame.to_csv("/content/drive/My Drive/Meus testes de dados/dadosestado.csv")
frame
# Out:
#           date   region      state  cases  deaths
# 0   2020-02-26  Sudeste  São Paulo      1       0
# 1   2020-02-27  Sudeste  São Paulo      1       0
# 2   2020-02-28  Sudeste  São Paulo      1       0
# 3   2020-02-29  Sudeste  São Paulo      2       0
# 4   2020-03-01  Sudeste  São Paulo      2       0
# ..         ...      ...        ...    ...     ...
# 31  2020-04-22    Norte    Roraima    280       3
# 32  2020-04-23    Norte    Roraima    297       3
# 33  2020-04-24    Norte    Roraima    304       3
# 34  2020-04-25    Norte    Roraima    345       3
# 35  2020-04-26    Norte    Roraima    401       4
#
# [1194 rows x 5 columns]

# %% [markdown]
# ## Numero Casos

# %%
import matplotlib.pyplot as plt
for i in range(len(d)):
  p = sns.catplot(x='date',y='cases', data=dadosPorEstado[d[i]],
                  kind='bar',palette="GnBu_d",
                  aspect=3)
  for ax in p.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')
  Casos_confimados = dadosPorEstado[d[i]]['cases']
  Casos_confimados.index = range(Casos_confimados.shape[0])
  plt.title(d[i]+' casos totais: '+str(Casos_confimados[Casos_confimados.shape[0]-1]))
  print(p)
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c871240>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8f5b70>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8060b8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8f5390>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c82ea20>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c839668>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c7c5400>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c7d27f0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8856d8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c64aeb8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3bf74748>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c81e8d0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c839668>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c470e80>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c2cf860>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8f54a8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8f5f28>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b55cd30>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b80a2b0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b3be0f0>
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b424828>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b0d0c88>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8060b8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8f5198>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a9686a0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3ac21438>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3c8f54a8>

# %% [markdown]
# ## Numero de mortes

# %%
for i in range(len(d)):
  p = sns.catplot(x='date',y='deaths', data=dadosPorEstado[d[i]],
                  kind='bar',palette="GnBu_d",
                  aspect=3)
  for ax in p.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')
  Mortes_confirmadas = dadosPorEstado[d[i]]['deaths']
  Mortes_confirmadas.index = range(Mortes_confirmadas.shape[0])
  plt.title(d[i]+' mortes totais: '+str(Mortes_confirmadas[Mortes_confirmadas.shape[0]-1]))
  print(p)
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a9fcfd0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a39830ba8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a397eda58>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a395f5748>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a392a47f0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a39265240>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a390a8cc0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a38ec9ba8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a38be6278>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a38a00518>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a6affd0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a399a1d68>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a4ac400>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a4ac780>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a49e390>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b9c4898>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b844b38>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b9eec50>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3ada9080>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b00a6d8>
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b9c29e8>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3bb94438>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a614588>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3ab87a20>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a39a57fd0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3b3de8d0>
# <seaborn.axisgrid.FacetGrid object at 0x7f2a3a14c048>

# %%
d[0]
Mortes_confirmadas[Mortes_confirmadas.shape[0]-1]
# Out:
# 4
